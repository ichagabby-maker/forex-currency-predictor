# %%
import sys
# !{sys.executable} -m pip install autots
from autots import AutoTS
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Collecting autots
#   Downloading autots-0.6.21-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.12/dist-packages (from autots) (2.0.2)
# Requirement already satisfied: pandas>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from autots) (2.2.2)
# Requirement already satisfied: statsmodels>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from autots) (0.14.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from autots) (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.25.0->autots) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.25.0->autots) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=0.25.0->autots) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->autots) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->autots) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->autots) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.10.0->autots) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from statsmodels>=0.10.0->autots) (25.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=0.25.0->autots) (1.17.0)
# Downloading autots-0.6.21-py3-none-any.whl (974 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.9/974.9 kB 36.9 MB/s eta 0:00:00
# Installing collected packages: autots
# Successfully installed autots-0.6.21

# %%
#loading data
data = pd.read_csv("Foreign_Exchange_Rates.xls")
data.head()
# Out:
#    Unnamed: 0  Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$  \
# 0           0  03-01-2000                            1.5172
# 1           1  04-01-2000                            1.5239
# 2           2  05-01-2000                            1.5267
# 3           3  06-01-2000                            1.5291
# 4           4  07-01-2000                            1.5272
#
#   EURO AREA - EURO/US$ NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0               0.9847                              1.9033
# 1                 0.97                              1.9238
# 2               0.9676                              1.9339
# 3               0.9686                              1.9436
# 4               0.9714                               1.938
#
#   UNITED KINGDOM - UNITED KINGDOM POUND/US$ BRAZIL - REAL/US$  \
# 0                                    0.6146             1.805
# 1                                    0.6109            1.8405
# 2                                    0.6092             1.856
# 3                                     0.607              1.84
# 4                                    0.6104             1.831
#
#   CANADA - CANADIAN DOLLAR/US$ CHINA - YUAN/US$  \
# 0                       1.4465           8.2798
# 1                       1.4518           8.2799
# 2                       1.4518           8.2798
# 3                       1.4571           8.2797
# 4                       1.4505           8.2794
#
#   HONG KONG - HONG KONG DOLLAR/US$  ... DENMARK - DANISH KRONE/US$  \
# 0                           7.7765  ...                      7.329
# 1                           7.7775  ...                      7.218
# 2                            7.778  ...                      7.208
# 3                           7.7785  ...                     7.2125
# 4                           7.7783  ...                     7.2285
#
#   JAPAN - YEN/US$ MALAYSIA - RINGGIT/US$ NORWAY - NORWEGIAN KRONE/US$  \
# 0           101.7                    3.8                        7.964
# 1          103.09                    3.8                        7.934
# 2          103.77                    3.8                        7.935
# 3          105.19                    3.8                         7.94
# 4          105.17                    3.8                        7.966
#
#   SWEDEN - KRONA/US$ SRI LANKA - SRI LANKAN RUPEE/US$ SWITZERLAND - FRANC/US$  \
# 0              8.443                             72.3                  1.5808
# 1               8.36                            72.65                  1.5565
# 2              8.353                            72.95                  1.5526
# 3             8.3675                            72.95                   1.554
# 4              8.415                            73.15                  1.5623
#
#   TAIWAN - NEW TAIWAN DOLLAR/US$ THAILAND - BAHT/US$ Unnamed: 24
# 0                          31.38               36.97         NaN
# 1                           30.6               37.13         NaN
# 2                           30.8                37.1         NaN
# 3                          31.75               37.62         NaN
# 4                          30.85                37.3         NaN
#
# [5 rows x 25 columns]

# %%
data.describe()
# Out:
#       Time Serie  SRI LANKA - SRI LANKAN RUPEE/US$  Unnamed: 24
# count          0                               0.0          0.0
# mean         NaT                               NaN          NaN
# min          NaT                               NaN          NaN
# 25%          NaT                               NaN          NaN
# 50%          NaT                               NaN          NaN
# 75%          NaT                               NaN          NaN
# max          NaT                               NaN          NaN
# std          NaN                               NaN          NaN

# %%
data.isnull().sum()
# Out:
# Time Serie                                   0
# AUSTRALIA - AUSTRALIAN DOLLAR/US$            0
# EURO AREA - EURO/US$                         0
# NEW ZEALAND - NEW ZELAND DOLLAR/US$          0
# UNITED KINGDOM - UNITED KINGDOM POUND/US$    0
# BRAZIL - REAL/US$                            0
# CANADA - CANADIAN DOLLAR/US$                 0
# CHINA - YUAN/US$                             0
# HONG KONG - HONG KONG DOLLAR/US$             0
# INDIA - INDIAN RUPEE/US$                     0
# KOREA - WON/US$                              0
# MEXICO - MEXICAN PESO/US$                    0
# SOUTH AFRICA - RAND/US$                      0
# SINGAPORE - SINGAPORE DOLLAR/US$             0
# DENMARK - DANISH KRONE/US$                   0
# JAPAN - YEN/US$                              0
# MALAYSIA - RINGGIT/US$                       0
# NORWAY - NORWEGIAN KRONE/US$                 0
# SWEDEN - KRONA/US$                           0
# SRI LANKA - SRI LANKAN RUPEE/US$             0
# SWITZERLAND - FRANC/US$                      0
# TAIWAN - NEW TAIWAN DOLLAR/US$               0
# THAILAND - BAHT/US$                          0
# Unnamed: 24                                  0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 24 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Time Serie                                 0 non-null      datetime64[ns]
#  1   AUSTRALIA - AUSTRALIAN DOLLAR/US$          0 non-null      object
#  2   EURO AREA - EURO/US$                       0 non-null      object
#  3   NEW ZEALAND - NEW ZELAND DOLLAR/US$        0 non-null      object
#  4   UNITED KINGDOM - UNITED KINGDOM POUND/US$  0 non-null      object
#  5   BRAZIL - REAL/US$                          0 non-null      object
#  6   CANADA - CANADIAN DOLLAR/US$               0 non-null      object
#  7   CHINA - YUAN/US$                           0 non-null      object
#  8   HONG KONG - HONG KONG DOLLAR/US$           0 non-null      object
#  9   INDIA - INDIAN RUPEE/US$                   0 non-null      object
#  10  KOREA - WON/US$                            0 non-null      object
#  11  MEXICO - MEXICAN PESO/US$                  0 non-null      object
#  12  SOUTH AFRICA - RAND/US$                    0 non-null      object
#  13  SINGAPORE - SINGAPORE DOLLAR/US$           0 non-null      object
#  14  DENMARK - DANISH KRONE/US$                 0 non-null      object
#  15  JAPAN - YEN/US$                            0 non-null      object
#  16  MALAYSIA - RINGGIT/US$                     0 non-null      object
#  17  NORWAY - NORWEGIAN KRONE/US$               0 non-null      object
#  18  SWEDEN - KRONA/US$                         0 non-null      object
#  19  SRI LANKA - SRI LANKAN RUPEE/US$           0 non-null      int64
#  20  SWITZERLAND - FRANC/US$                    0 non-null      object
#  21  TAIWAN - NEW TAIWAN DOLLAR/US$             0 non-null      object
#  22  THAILAND - BAHT/US$                        0 non-null      object
#  23  Unnamed: 24                                0 non-null      float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(21)
# memory usage: 0.0+ bytes

# %%
data = data.dropna()
data['Time Serie'] = pd.to_datetime(data['Time Serie'], format='%d-%m-%Y')

# %%
#Pre-Processing code here

#selecting currency

options = {
    'AUSTRALIAN DOLLAR': 'AUSTRALIA - AUSTRALIAN DOLLAR/US$',
    'EURO': 'EURO AREA - EURO/US$',
    'NEW ZEALAND DOLLAR': 'NEW ZEALAND - NEW ZELAND DOLLAR/US$',
    'GREAT BRITAIN POUNDS': 'UNITED KINGDOM - UNITED KINGDOM POUND/US$',
    'BRAZILIAN REAL': 'BRAZIL - REAL/US$',
    'CANADIAN DOLLAR': 'CANADA - CANADIAN DOLLAR/US$',
    'CHINESE YUAN$': 'CHINA - YUAN/US$',
    'HONG KONG DOLLAR': 'HONG KONG - HONG KONG DOLLAR/US$',
    'INDIAN RUPEE': 'INDIA - INDIAN RUPEE/US$',
    'KOREAN WON$': 'KOREA - WON/US$',
    'MEXICAN PESO': 'MEXICO - MEXICAN PESO/US$',
    'SOUTH AFRICAN RAND$': 'SOUTH AFRICA - RAND/US$',
    'SINGAPORE DOLLAR': 'SINGAPORE - SINGAPORE DOLLAR/US$',
    'DANISH KRONE': 'DENMARK - DANISH KRONE/US$',
    'JAPANESE YEN$': 'JAPAN - YEN/US$',
    'MALAYSIAN RINGGIT': 'MALAYSIA - RINGGIT/US$',
    'NORWEGIAN KRONE': 'NORWAY - NORWEGIAN KRONE/US$',
    'SWEDEN KRONA': 'SWEDEN - KRONA/US$',
    'SRILANKAN RUPEE': 'SRI LANKA - SRI LANKAN RUPEE/US$',
    'SWISS FRANC': 'SWITZERLAND - FRANC/US$',
    'NEW TAIWAN DOLLAR': 'TAIWAN - NEW TAIWAN DOLLAR/US$',
    'THAI BAHT': 'THAILAND - BAHT/US$'
}

selected_option = 'SRILANKAN RUPEE' #select currency here to train model

# Drop the 'Unnamed: 0' column as it appears to be an artifact of CSV export/import
if 'Unnamed: 0' in data.columns:
    data = data.drop(columns=['Unnamed: 0'])

# Convert the selected currency column to numeric, coercing errors to NaN
data[options[selected_option]] = pd.to_numeric(data[options[selected_option]], errors='coerce')

# Drop rows where the selected currency value is NaN after conversion
# This handles cases where original values were 'ND' or other non-numeric strings
data = data.dropna(subset=[options[selected_option]])

# %%
# EDA code here

# %%
#selecting currency

options = {
    'AUSTRALIAN DOLLAR': 'AUSTRALIA - AUSTRALIAN DOLLAR/US$',
    'EURO': 'EURO AREA - EURO/US$',
    'NEW ZEALAND DOLLAR': 'NEW ZEALAND - NEW ZEALAND DOLLAR/US$',
    'GREAT BRITAIN POUNDS': 'UNITED KINGDOM - UNITED KINGDOM POUND/US$',
    'BRAZILIAN REAL': 'BRAZIL - REAL/US$',
    'CANADIAN DOLLAR': 'CANADA - CANADIAN DOLLAR/US$',
    'CHINESE YUAN$': 'CHINA - YUAN/US$',
    'HONG KONG DOLLAR': 'HONG KONG - HONG KONG DOLLAR/US$',
    'INDIAN RUPEE': 'INDIA - INDIAN RUPEE/US$',
    'KOREAN WON$': 'KOREA - WON/US$',
    'MEXICAN PESO': 'MEXICO - MEXICAN PESO/US$',
    'SOUTH AFRICAN RAND$': 'SOUTH AFRICA - RAND/US$',
    'SINGAPORE DOLLAR': 'SINGAPORE - SINGAPORE DOLLAR/US$',
    'DANISH KRONE': 'DENMARK - DANISH KRONE/US$',
    'JAPANESE YEN$': 'JAPAN - YEN/US$',
    'MALAYSIAN RINGGIT': 'MALAYSIA - RINGGIT/US$',
    'NORWEGIAN KRONE': 'NORWAY - NORWEGIAN KRONE/US$',
    'SWEDEN KRONA': 'SWEDEN - KRONA/US$',
    'SRILANKAN RUPEE': 'SRI LANKA - SRI LANKAN RUPEE/US$',
    'SWISS FRANC': 'SWITZERLAND - FRANC/US$',
    'NEW TAIWAN DOLLAR': 'TAIWAN - NEW TAIWAN DOLLAR/US$',
    'THAI BAHT': 'THAILAND - BAHT/US$'
}

selected_option = 'SRILANKAN RUPEE' #select currency here to train model

# %%
#predictive modelling code here

# we are using autots library for predictive modelling as an example. Please compare different models(Traditional ML, DeepLearning or Transformers) and select the bestmodel.
forecast=10 #no of days for forecasting

model = AutoTS(forecast_length=int(forecast), frequency='infer', ensemble='simple', drop_data_older_than_periods=200)
model = model.fit(data, date_col = 'Time Serie', value_col=options[selected_option], id_col=None)

# %%
#generating forecasts
prediction = model.predict()
forecast = prediction.forecast

# %%
forecast
